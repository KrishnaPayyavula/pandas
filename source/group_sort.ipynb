# %%
import pandas as pd
reviews = pd.read_csv("/Users/krishna/Career/Python/pandas/data/datasets/winemag-data-130k-v2.csv", index_col=0)
pd.set_option("display.max_rows", 8)

# %%
daa =reviews.groupby('points')

# Get top 3 taste twitter handle in each group
def top3_taste(group):
    return group.sort_values(by='price', ascending=False)[:3]

daa.apply(top3_taste)

# Get top 3 taste twitter handle in each grou
# Out:
#               country                                        description  \
# points
# 80     103989      US  This suffers from major problems. It has all t...
#        28569       US  Smells and tastes like caramel and stewed cher...
#        65350       US  Blended from Syrah, Mourvèdre and the two Cabe...
# 81     11369    Spain  Aromas of blueberry and soupy fruits lack defi...
# ...               ...                                                ...
# 99     44994    Italy  This stunning wine is all about extreme elegan...
# 100    111753  France  Almost black in color, this stunning wine is g...
#        111755  France  This is the finest Cheval Blanc for many years...
#        122935  France  Full of ripe fruit, opulent and concentrated, ...
#
#                                                      designation  points  \
# points
# 80     103989                               Miljenko's Old Vines      80
# ...
